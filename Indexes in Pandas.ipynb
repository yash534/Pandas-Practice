# %%
import pandas as pd

# %%
df = pd.read_excel(r"Y:\DataSets\emp-data.xlsx")

# %%
df
# Out:
#                    Name  Gender   Department  Age Date Joined  Salary  Rating  \
# 0          Barr Faughny  Female  Procurement   39  2018-02-06   68010       6
# 1   Dennison Crosswaite    Male      Website   26  2017-09-16   90700       3
# 2       Gunar Cockshoot    Male      Website   31  2017-05-11   48950       4
# 3        Wilone O'Kielt  Female      Website   43  2017-10-29  114870       2
# 4          Gigi Bohling    Male        Sales   33  2017-01-08   74550       3
# ..                  ...     ...          ...  ...         ...     ...     ...
# 95     Verney Sloegrave    Male        Sales   19  2017-04-04   84500       5
# 96       Murry Dryburgh    Male      Website   32  2017-05-19   69070       3
# 97       Hannis January    Male  Procurement   29  2018-02-05   29530       6
# 98       Brigid Jeffrey  Female           HR   34  2017-02-02   53910       5
# 99       Glennis Fussen  Female  Procurement   21  2016-04-27   58370       4
#
# ...

# %%
df = pd.read_excel(r"Y:\DataSets\emp-data.xlsx", index_col = 'Department')
df
# Out:
#                             Name  Gender  Age Date Joined  Salary  Rating  \
# Department
# Procurement         Barr Faughny  Female   39  2018-02-06   68010       6
# Website      Dennison Crosswaite    Male   26  2017-09-16   90700       3
# Website          Gunar Cockshoot    Male   31  2017-05-11   48950       4
# Website           Wilone O'Kielt  Female   43  2017-10-29  114870       2
# Sales               Gigi Bohling    Male   33  2017-01-08   74550       3
# ...                          ...     ...  ...         ...     ...     ...
# Sales           Verney Sloegrave    Male   19  2017-04-04   84500       5
# Website           Murry Dryburgh    Male   32  2017-05-19   69070       3
# Procurement       Hannis January    Male   29  2018-02-05   29530       6
# HR                Brigid Jeffrey  Female   34  2017-02-02   53910       5
# Procurement       Glennis Fussen  Female   21  2016-04-27   58370       4
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      Department                 Name  Gender  Age Date Joined  Salary  Rating  \
# 0   Procurement         Barr Faughny  Female   39  2018-02-06   68010       6
# 1       Website  Dennison Crosswaite    Male   26  2017-09-16   90700       3
# 2       Website      Gunar Cockshoot    Male   31  2017-05-11   48950       4
# 3       Website       Wilone O'Kielt  Female   43  2017-10-29  114870       2
# 4         Sales         Gigi Bohling    Male   33  2017-01-08   74550       3
# ..          ...                  ...     ...  ...         ...     ...     ...
# 95        Sales     Verney Sloegrave    Male   19  2017-04-04   84500       5
# 96      Website       Murry Dryburgh    Male   32  2017-05-19   69070       3
# 97  Procurement       Hannis January    Male   29  2018-02-05   29530       6
# 98           HR       Brigid Jeffrey  Female   34  2017-02-02   53910       5
# 99  Procurement       Glennis Fussen  Female   21  2016-04-27   58370       4
#
# ...

# %%
 df.set_index('Department', inplace = True)

# %%
df
# Out:
#                             Name  Gender  Age Date Joined  Salary  Rating  \
# Department
# Procurement         Barr Faughny  Female   39  2018-02-06   68010       6
# Website      Dennison Crosswaite    Male   26  2017-09-16   90700       3
# Website          Gunar Cockshoot    Male   31  2017-05-11   48950       4
# Website           Wilone O'Kielt  Female   43  2017-10-29  114870       2
# Sales               Gigi Bohling    Male   33  2017-01-08   74550       3
# ...                          ...     ...  ...         ...     ...     ...
# Sales           Verney Sloegrave    Male   19  2017-04-04   84500       5
# Website           Murry Dryburgh    Male   32  2017-05-19   69070       3
# Procurement       Hannis January    Male   29  2018-02-05   29530       6
# HR                Brigid Jeffrey  Female   34  2017-02-02   53910       5
# Procurement       Glennis Fussen  Female   21  2016-04-27   58370       4
#
# ...

# %%
df.loc['Website']
# Out:
#                            Name  Gender  Age Date Joined  Salary  Rating  \
# Department
# Website     Dennison Crosswaite    Male   26  2017-09-16   90700       3
# Website         Gunar Cockshoot    Male   31  2017-05-11   48950       4
# Website          Wilone O'Kielt  Female   43  2017-10-29  114870       2
# Website             Kaine Padly    Male   20  2017-03-20  107700       2
# Website            Ches Bonnell    Male   37  2016-11-22   88050       3
# Website          Andria Kimpton    Male   30  2016-09-18   69120       3
# Website             Brien Boise  Female   31  2017-10-12   58100       2
# Website          Dotty Strutley  Female   31  2016-05-10   41980       2
# Website             Van Tuxwell  Female   25  2017-11-13   80700       4
# Website          Camilla Castle  Female   33  2016-12-27   75480       4
# Website         Niall Selesnick  Female   29  2016-01-11   34980       2
# Website        Madge McCloughen     NaN   32  2018-02-01   91310       1
# ...

# %%
df.reset_index(inplace = True)

# %%
#MultiIndexing

df.set_index(['Department', 'Manager'], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [18], in <cell line: 3>()
#       1 #MultiIndexing
# ----> 3 df.set_index(['Department', 'Manager'], inplace = True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# -> 5494     raise KeyError(f"None of {missing} are in the columns")
#    5496 if inplace:
# ...

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#      Department Manager  Rating                 Name  Gender  Age Date Joined  \
# 0   Procurement   Carla       6         Barr Faughny  Female   39  2018-02-06
# 1       Website     Ian       3  Dennison Crosswaite    Male   26  2017-09-16
# 2       Website   Carla       4      Gunar Cockshoot    Male   31  2017-05-11
# 3       Website     Ian       2       Wilone O'Kielt  Female   43  2017-10-29
# 4         Sales     Ram       3         Gigi Bohling    Male   33  2017-01-08
# ..          ...     ...     ...                  ...     ...  ...         ...
# 95        Sales   Carla       5     Verney Sloegrave    Male   19  2017-04-04
# 96      Website   Carla       3       Murry Dryburgh    Male   32  2017-05-19
# 97  Procurement    Fred       6       Hannis January    Male   29  2018-02-05
# 98           HR   Carla       5       Brigid Jeffrey  Female   34  2017-02-02
# 99  Procurement   Carla       4       Glennis Fussen  Female   21  2016-04-27
#
# ...

# %%
#MultiIndexing

df.set_index(['Department', 'Manager'], inplace = True)

# %%
df
# Out:
#                      Rating                 Name  Gender  Age Date Joined  \
# Department  Manager
# Procurement Carla         6         Barr Faughny  Female   39  2018-02-06
# Website     Ian           3  Dennison Crosswaite    Male   26  2017-09-16
#             Carla         4      Gunar Cockshoot    Male   31  2017-05-11
#             Ian           2       Wilone O'Kielt  Female   43  2017-10-29
# Sales       Ram           3         Gigi Bohling    Male   33  2017-01-08
# ...                     ...                  ...     ...  ...         ...
#             Carla         5     Verney Sloegrave    Male   19  2017-04-04
# Website     Carla         3       Murry Dryburgh    Male   32  2017-05-19
# Procurement Fred          6       Hannis January    Male   29  2018-02-05
# HR          Carla         5       Brigid Jeffrey  Female   34  2017-02-02
# Procurement Carla         4       Glennis Fussen  Female   21  2016-04-27
#
# ...

# %%
df.loc['Sales', 'Carla']
# Out:
# C:\Users\yashp\AppData\Local\Temp\ipykernel_18844\984560988.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df.loc['Sales', 'Carla']
#                     Rating              Name  Gender  Age Date Joined  Salary  \
# Department Manager
# Sales      Carla         3     Lindy Guillet    Male   22  2017-03-07  112780
#            Carla         6        Tatum Hush  Female   28  2016-12-10   53240
#            Carla         3        Oran Buxcy  Female   38  2016-11-13   56870
#            Carla         5  Verney Sloegrave    Male   19  2017-04-04   84500
#
#                                                             Picture
# Department Manager
# Sales      Carla      https://files.chandoo.org/pbix/img/men-20.jpg
#            Carla    https://files.chandoo.org/pbix/img/women-27.jpg
#            Carla    https://files.chandoo.org/pbix/img/women-43.jpg
#            Carla      https://files.chandoo.org/pbix/img/men-49.jpg

# %%
df.iloc[1]
# Out:
# Rating                                                    3
# Name                                    Dennison Crosswaite
# Gender                                                 Male
# Age                                                      26
# Date Joined                             2017-09-16 00:00:00
# Salary                                                90700
# Picture        https://files.chandoo.org/pbix/img/men-1.jpg
# Name: (Website, Ian), dtype: object
